# %%
import lancedb
from dotenv import load_dotenv

load_dotenv()

db = lancedb.connect(uri = "../knowledge_base")
db
# Out:
# LanceDBConnection(uri='c:\\Users\\tasmi\\MLOPS\\RAG_mlops25\\rag\\src\\rag\\exploration\\..\\knowledge_base')

# %%
db["articles"]
# Out:
# LanceTable(name='articles', version=1, _conn=LanceDBConnection(uri='c:\\Users\\tasmi\\MLOPS\\RAG_mlops25\\rag\\src\\rag\\exploration\\..\\knowledge_base'))

# %%
db["articles"].to_pandas()
# Out:
# Empty DataFrame
# Columns: [document_name, filepath, content, embedding]
# Index: []

# %%
db["articles"].search("vad äter pandor?").to_pandas()
# Out:
# ERROR:root:Could not find API key for cohere
# WARNING:root:Error occurred: Please set the COHERE_API_KEY environment variable.
#  Retrying in 3.589263348511819 seconds (retry 1 of 7)
#
# ERROR:root:Could not find API key for cohere
# WARNING:root:Error occurred: Please set the COHERE_API_KEY environment variable.
#  Retrying in 7.310599385837662 seconds (retry 2 of 7)
#
# ERROR:root:Could not find API key for cohere
# WARNING:root:Error occurred: Please set the COHERE_API_KEY environment variable.
#  Retrying in 25.78886155891054 seconds (retry 3 of 7)
