# %%
import lancedb
from dotenv import load_dotenv

load_dotenv()

db = lancedb.connect(uri = "../knowledge_base")
db
# Out:
# LanceDBConnection(uri='c:\\Users\\tasmi\\MLOPS\\RAG_mlops25\\rag\\src\\rag\\exploration\\..\\knowledge_base')

# %%
db["articles"]
# Out:
# LanceTable(name='articles', version=11, _conn=LanceDBConnection(uri='c:\\Users\\tasmi\\MLOPS\\RAG_mlops25\\rag\\src\\rag\\exploration\\..\\knowledge_base'))

# %%
db["articles"].to_pandas()
# Out:
#    document_name                                           filepath  \
# 0   fisk (1).txt  C:\Users\tasmi\mlops\RAG_mlops25\rag\src\rag\d...
# 1  kanin (1).txt  C:\Users\tasmi\mlops\RAG_mlops25\rag\src\rag\d...
# 2     krabba.txt  C:\Users\tasmi\mlops\RAG_mlops25\rag\src\rag\d...
# 3      panda.txt  C:\Users\tasmi\mlops\RAG_mlops25\rag\src\rag\d...
# 4      tiger.txt  C:\Users\tasmi\mlops\RAG_mlops25\rag\src\rag\d...
#
#                                              content  \
# 0  Fiskar (Pisces) är en grupp vattenlevande rygg...
# 1  Harar och kaniner\n\nArtikel\nDiskussion\nLäs\...
# 2  Krabbor (Brachyura) är en delordning av vatten...
# 3  Jättepanda (Ailuropoda melanoleuca), panda, pa...
# 4  Tiger (Panthera tigris) är ett kattdjur som en...
#
#                                            embedding
# 0  [0.05697632, 0.020736694, -0.028640747, -0.049...
# 1  [-0.021514893, -0.024353027, 0.0044822693, -0....
# 2  [0.011009216, -0.03277588, -0.049041748, -0.04...
# 3  [0.07891846, 0.018447876, -0.00818634, -0.0604...
# 4  [0.022979736, 0.03173828, -0.004386902, -0.050...

# %%
db["articles"].search("vad äter pandor?").to_pandas()
# Out:
#    document_name                                           filepath  \
# 0      panda.txt  C:\Users\tasmi\mlops\RAG_mlops25\rag\src\rag\d...
# 1     krabba.txt  C:\Users\tasmi\mlops\RAG_mlops25\rag\src\rag\d...
# 2      tiger.txt  C:\Users\tasmi\mlops\RAG_mlops25\rag\src\rag\d...
# 3   fisk (1).txt  C:\Users\tasmi\mlops\RAG_mlops25\rag\src\rag\d...
# 4  kanin (1).txt  C:\Users\tasmi\mlops\RAG_mlops25\rag\src\rag\d...
#
#                                              content  \
# 0  Jättepanda (Ailuropoda melanoleuca), panda, pa...
# 1  Krabbor (Brachyura) är en delordning av vatten...
# 2  Tiger (Panthera tigris) är ett kattdjur som en...
# 3  Fiskar (Pisces) är en grupp vattenlevande rygg...
# 4  Harar och kaniner\n\nArtikel\nDiskussion\nLäs\...
#
#                                            embedding  _distance
# 0  [0.07891846, 0.018447876, -0.00818634, -0.0604...   0.806009
# 1  [0.011009216, -0.03277588, -0.049041748, -0.04...   0.968804
# 2  [0.022979736, 0.03173828, -0.004386902, -0.050...   0.989742
# 3  [0.05697632, 0.020736694, -0.028640747, -0.049...   1.145227
# 4  [-0.021514893, -0.024353027, 0.0044822693, -0....   1.199942
